# %% [markdown]
# # **Computational Drug**
#
# In this Jupyter notebook, we will  build a real-life **Biology Computational project**  In the end we will be building a machine learning model using the ChEMBL bioactivity data.Our target is dataset containing the bioactivity data for Hepatitis C virus NS3 protease/helicase
#
# Francisco Garcia
# ---

# %% [markdown]
# ## **1- Download Bioactivity Data**

# %% [markdown]
# #### **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of October 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Installing the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /usr/local/lib/python3.6/dist-packages (0.10.2)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.6/dist-packages (from chembl_webresource_client) (2.23.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.6/dist-packages (from chembl_webresource_client) (1.24.3)
# Requirement already satisfied: requests-cache>=0.4.7 in /usr/local/lib/python3.6/dist-packages (from chembl_webresource_client) (0.5.2)
# Requirement already satisfied: easydict in /usr/local/lib/python3.6/dist-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2020.12.5)

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for coronavirus**

# %%
# Target search for hepatitis
target = new_client.target
target_query = target.search('hepatitis')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references  ... tax_id
# 0                                                  []  ...  10407
# 1                                                  []  ...  11103
# 2                                                  []  ...  11138
# 3                                                  []  ...  12092
# 4                                                  []  ...  35269
# 5   [{'xref_id': 'P26664', 'xref_name': None, 'xre...  ...  11104
# 6                                                  []  ...  12639
# 7   [{'xref_id': 'Q15004', 'xref_name': None, 'xre...  ...   9606
# 8   [{'xref_id': 'D2K2A8', 'xref_name': None, 'xre...  ...  11103
# 9                                                  []  ...  11142
# 10  [{'xref_id': 'Hepatic_lipase', 'xref_name': No...  ...   9606
# 11  [{'xref_id': 'A3EZI9', 'xref_name': None, 'xre...  ...  11103
# 12  [{'xref_id': 'Q8JXU8', 'xref_name': None, 'xre...  ...  11103
# 13                                                 []  ...   9606
# 14                                                 []  ...  11103
# 15                                                 []  ...  10116
# 16  [{'xref_id': 'Q69422', 'xref_name': None, 'xre...  ...  39113
# 17  [{'xref_id': 'P37288', 'xref_name': None, 'xre...  ...   9606
# 18  [{'xref_id': 'P30560', 'xref_name': None, 'xre...  ...  10116
# 19  [{'xref_id': 'P34927', 'xref_name': None, 'xre...  ...  10090
# 20                                                 []  ...  10116
# 21  [{'xref_id': 'P04181', 'xref_name': None, 'xre...  ...   9606
# 22  [{'xref_id': 'P78540', 'xref_name': None, 'xre...  ...   9606
# 23                                                 []  ...  79684
# 24                                                 []  ...  10090
# 25                                                 []  ...   9606
# 26                                                 []  ...   9606
# 27                                                 []  ...   9606
# 28                                                 []  ...   9606
# 29  [{'xref_id': 'P07306', 'xref_name': None, 'xre...  ...   9606
# 30                                                 []  ...  10116
# 31                                                 []  ...   9606
# 32  [{'xref_id': 'Q04828', 'xref_name': None, 'xre...  ...   9606
# 33                                                 []  ...  10116
# 34                                                 []  ...   9606
# 35                                                 []  ...   9606
#
# [36 rows x 9 columns]

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Hepatitis C virus NS3 protease/helicase* (10º entry)**

# %% [markdown]
# We will assign the 10º entry (which corresponds to the target protein, Hepatitis C virus NS3 protease/helicase) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[11]
selected_target
# Out:
# 'CHEMBL4893'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Hepatitis C virus NS3 protease/helicase* (CHEMBL4893) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)
df
# Out:
#     activity_comment  activity_id  ... upper_value value
# 0               None       115491  ...        None  0.42
# 1               None       129448  ...        None  0.35
# 2               None       130845  ...        None  4.34
# 3               None       133287  ...        None   2.5
# 4               None       134500  ...        None  0.57
# ..               ...          ...  ...         ...   ...
# 306             None      1840273  ...        None  73.0
# 307             None      1840274  ...        None  38.0
# 308             None      1840275  ...        None  27.0
# 309             None      1840276  ...        None  10.0
# 310             None      1840277  ...        None  27.0
#
# [311 rows x 43 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity__hepatitis0.csv**.

# %%
df.to_csv('bioactivity_data_hepatitis0.csv', index=False)

# %% [markdown]
# ## **Copying files to Google Drive**

# %% [markdown]
# Firstly, we need to mount the Google Drive into Colab so that we can have access to our Google adrive from within Colab.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Next, we create a **data** folder in our **Colab Notebooks** folder on Google Drive.

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/Data_hepatitis"

# %%
! cp bioactivity_data_hepatitis0.csv "/content/gdrive/My Drive/Colab Notebooks/Data_hepatitis"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/Data_hepatitis"
# Out:
# total 176
# -rw------- 1 root root 179392 Dec 14 14:40 bioactivity_data_hepatitis0.csv

# %% [markdown]
# Let's see the CSV files that we have so far.

# %%
! ls
# Out:
# bioactivity_data.csv  bioactivity_data_hepatitis0.csv  gdrive  sample_data

# %% [markdown]
# Taking a glimpse of the **bioactivity_data.csv** file that we've just created.

# %%
! head bioactivity_data.csv
# Out:
# activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,1411512,[],CHEMBL831669,Inhibitory concentration against hepatitis C NS4A protease,B,BAO_0000190,BAO_0000357,single protein format,CC[C@H](C)[C@H](NC(=O)[C@H](CCCN=C(N)N)NC(=O)CNC(=O)[C@@H](NC(=O)[C@@H](NC(=O)[C@@H](NC(=O)[C@@H](NC(=O)[C@@H](N)CS)C(C)C)C(C)C)[C@@H](C)CC)C(C)C)C(=O)N[C@H](C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](CO)C(=O)NCC(=O)N[C@@H](CCCCN)C(=O)O)C(C)C,,,CHEMBL1145280,J. Med. Chem.,2005,"{'bei': '4.99', 'le': None, 'lle': None, 'sei': None}",CHEMBL408166,,CHEMBL408166,6.70,False,http://www.openphacts.org/units/Nanomolar,362342,=,1,True,=,,IC50,nM,,200.0,CHEMBL2364,Hepatitis C virus,Hepatitis C virus NS4A protein,11103,,,IC50,uM,UO_0000065,,0.2
# ,1411513,[],CHEMBL833555,Inhibitory concentration against hepatitis C virus NS4A active site,B,BAO_0000190,BAO_0000357,single protein format,CC[C@H](C)[C@H](NC(=O)[C@@H](NC(=O)[C@H](CC(C)C)NC(=O)[C@H](CO)NC(=O)CNC(=O)[C@@H](N)CCCCN)C(C)C)C(=O)N[C@@H](CCCN=C(N)N)C(=O)NCC(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@@H](CS)C(=O)N[C@@H](CCCCN)C(=O)O)C(C)C)C(C)C)[C@@H](C)CC)C(C)C,,,CHEMBL1145280,J. Med. Chem.,2005,"{'bei': '4.55', 'le': None, 'lle': None, 'sei': None}",CHEMBL438893,,CHEMBL438893,6.70,False,http://www.openphacts.org/units/Nanomolar,362348,=,1,True,=,,IC50,nM,,200.0,CHEMBL2364,Hepatitis C virus,Hepatitis C virus NS4A protein,11103,,,IC50,uM,UO_0000065,,0.2
# ,1411514,[],CHEMBL833555,Inhibitory concentration against hepatitis C virus NS4A active site,B,BAO_0000190,BAO_0000357,single protein format,CC[C@H](C)[C@H](NC(=O)[C@@H](NC(=O)[C@H](CC(C)C)NC(=O)[C@@H](N)CO)C(C)C)C(=O)N[C@@H](CCCN=C(N)N)C(=O)NCC(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)O)C(C)C)[C@@H](C)CC)C(C)C,,,CHEMBL1145280,J. Med. Chem.,2005,"{'bei': '6.51', 'le': '0.13', 'lle': '8.16', 'sei': '1.63'}",CHEMBL361380,,CHEMBL361380,6.22,False,http://www.openphacts.org/units/Nanomolar,362349,=,1,True,=,,IC50,nM,,600.0,CHEMBL2364,Hepatitis C virus,Hepatitis C virus NS4A protein,11103,,,IC50,uM,UO_0000065,,0.6

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#     activity_comment  activity_id  ... upper_value value
# 0               None       115491  ...        None  0.42
# 1               None       129448  ...        None  0.35
# 2               None       130845  ...        None  4.34
# 3               None       133287  ...        None   2.5
# 4               None       134500  ...        None  0.57
# ..               ...          ...  ...         ...   ...
# 306             None      1840273  ...        None  73.0
# 307             None      1840274  ...        None  38.0
# 308             None      1840275  ...        None  27.0
# 309             None      1840276  ...        None  10.0
# 310             None      1840277  ...        None  27.0
#
# [307 rows x 43 columns]

# %% [markdown]
# We  had cleaned the missing data.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Iterate the *molecule_chembl_id* to a list**

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# ### **Iterate *canonical_smiles* to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# ### **Iterate *standard_value* to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# ### **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#     molecule_chembl_id  ... standard_value
# 0          CHEMBL13443  ...          420.0
# 1         CHEMBL346460  ...          350.0
# 2         CHEMBL348896  ...         4340.0
# 3         CHEMBL351702  ...         2500.0
# 4         CHEMBL351389  ...          570.0
# ..                 ...  ...            ...
# 302       CHEMBL390344  ...        73000.0
# 303       CHEMBL390344  ...        38000.0
# 304       CHEMBL390344  ...        27000.0
# 305       CHEMBL439547  ...        10000.0
# 306       CHEMBL439547  ...        27000.0
#
# [307 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('bioactivity_hepatitis_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 236
# -rw-r--r-- 1 root root   2593 Dec 14 14:14 bioactivity_data.csv
# -rw-r--r-- 1 root root 179392 Dec 14 14:37 bioactivity_data_hepatitis0.csv
# -rw-r--r-- 1 root root  45146 Dec 14 14:48 bioactivity_hepatitis_preprocessed_data.csv
# drwx------ 5 root root   4096 Dec 14 14:39 gdrive
# drwxr-xr-x 1 root root   4096 Dec  2 22:04 sample_data

# %% [markdown]
# Coping to the Google Drive

# %%
! cp bioactivity_hepatitis_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/Data_hepatitis"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/Data_hepatitis"
# Out:
# bioactivity_data_hepatitis0.csv  bioactivity_hepatitis_preprocessed_data.csv

# %% [markdown]
# ---
